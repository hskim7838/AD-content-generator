# %%
import os
import pandas as pd

# 1. 가상환경 경로를 강제 주입하여 pandas를 독립적으로 구동
sys_path_backup = sys.path.copy()
sys.path.insert(0, "/home/ai3/AD-content/CAIG/caig/lib/python3.10/site-packages")
import pandas as pd

# 2. 데이터프레임 로드 및 이미지 HTML 태그 변환
df = pd.read_csv('final_evaluation_summary.csv')

def render_image(filename):
    return f'<img src="images/{filename}" width="100" style="border-radius:6px; border:1px solid #ddd;"/>'

df_preview = df.copy()
df_preview.insert(0, 'Preview', df_preview['File'].apply(render_image))

# 3. 주피터 화면이 아닌 독립된 'dashboard.html' 파일로 내보내기
html_content = f"""
<html>
<head><title>품질 평가 종합 대시보드</title></head>
<body style="font-family: sans-serif; padding: 20px;">
    <h2>📊 18대 이미지 품질 평가 종합 대시보드</h2>
    {df_preview.to_html(escape=False, index=False)}
</body>
</html>
"""

with open('dashboard.html', 'w', encoding='utf-8') as f:
    f.write(html_content)

print("✨ 성공! 왼쪽 파일 탐색기에 'dashboard.html' 파일이 생성되었습니다.")
print("이 파일을 더블클릭하여 오픈하거나 새 창으로 열면 이미지와 수치를 한눈에 보실 수 있습니다!")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 2
#       1 import os
# ----> 2 import pandas as pd
#       3
#       4 # 1. 가상환경 경로를 강제 주입하여 pandas를 독립적으로 구동
#       5 sys_path_backup = sys.path.copy()
#
# File ~/AD-content/CAIG/caig/lib/python3.10/site-packages/pandas/__init__.py:19
#      16         _missing_dependencies.append(f"{_dependency}: {_e}")
#      18 if _missing_dependencies:  # pragma: no cover
# ---> 19     raise ImportError(
#      20         "Unable to import required dependencies:\n" + "\n".join(_missing_dependencies)
#      21     )
#      22 del _hard_dependencies, _dependency, _missing_dependencies
#      24 try:
#      25     # numpy compat
#
# ImportError: Unable to import required dependencies:
# numpy: Error importing numpy: you should not try to import numpy from
# ...
