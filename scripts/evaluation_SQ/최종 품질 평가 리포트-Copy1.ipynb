# %% [markdown]
# # 📊 최종 품질 평가 리포트
#
# | 파일명 | FID 영향도 | DINO Similarity | VGG 지각적 거리 |
# |:---|:---:|:---:|:---:|
# | `bakery_product1_20260703091903.07.png` | - | 0.8765 | 4.2686 |
# | `bakery_product1_20260706004603.23.png` | +0.0210 | 0.9384 | 5.3797 |
# | `bakery_product1_20260706013245.98.png` | -0.0150 | 0.9412 | 2.8018 |
# | `bakery_product1_20260706013830.62.png` | -0.0050 | 0.9586 | 4.5170 |
# | `bakery_product1_20260706014204.10.png` | -0.0120 | 0.9608 | 3.9344 |
# | `bakery_product1_20260706022332.69.png` | +0.0080 | 0.9199 | 3.0686 |
# | `bakery_product1_20260706022710.63.png` | +0.0310 | 0.9166 | 5.7189 |
# | `bakery_product1_20260706022959.44.png` | +0.0450 | 0.8630 | 6.6191 |
# | `bakery_product1_20260706023308.54.png` | -0.0020 | 0.9347 | 3.5250 |
# | `bakery_product1_20260706023621.53.png` | +0.0520 | 0.7855 | 7.0909 |
# | `bakery_product1_20260706023916.73.png` | +0.0110 | 0.9200 | 4.6893 |
# | `bakery_product1_20260706024842.26.png` | -0.0090 | 0.9354 | 3.8322 |
# | `bakery_product1_20260706040629.79.png` | -0.0180 | 0.9545 | 3.6769 |
# | `bakery_product1_20260706040929.78.png` | +0.0040 | 0.9289 | 4.1510 |
# | `bakery_product1_20260706084020.23.png` | -0.0140 | 0.9541 | 4.1777 |
# | `bakery_product1_20260706084607.93.png` | -0.0110 | 0.9433 | 3.4591 |
# | `bakery_product1_20260706090624.01.png` | -0.0060 | 0.9208 | 3.9961 |
#
# > **지표 설명:**
# > * **FID 영향도:** (-)는 품질 향상 기여, (+)는 품질 저하 기여.
# > * **DINO Similarity:** 1.0에 가까울수록 원본과 의미론적 구조가 동일 (높을수록 좋음).
# > * **VGG 지각적 거리:** 값이 낮을수록 시각적으로 원본과 유사 (낮을수록 좋음).
